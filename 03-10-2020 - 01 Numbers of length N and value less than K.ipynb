# %% [markdown]
# # Question 01

# %%
from IPython.display import Image
Image(filename='Program_01_Question.png')

# %%
class Solution:
    # @param A : list of integers
    # @param B : integer
    # @param C : integer
    # @return an integer
    def __init__(self, A, B, C):
        self.A=list(set(A))  # Makes distinct elements in list A
        self.B=B
        self.C=C      
    def solve(self):
        if self.A==[]:
            raise Exception("Please provide non-empty list(A)")
        elif self.B<=0 or self.C<=0:
            raise Exception("Please provide the values of B and C are positive integers ")

        from itertools import combinations_with_replacement 
        comb = combinations_with_replacement(self.A*2, self.B)
        List = []
        for i in list(comb):
            str_num=""
            for j in range(self.B):
                str_num = str_num+str(i[j])
            if len(str_num)>1:
                if str_num[0]!='0' and int(str_num)<self.C:
                    List.append(int(str_num))
            elif int(str_num)<self.C:
                List.append(int(str_num))
        print(list(set(List)))

# %%
sol = Solution([0, 1, 5], 1, 2)
sol.solve()
# Out:
# [0, 1]

# %%
sol = Solution([0, 1, 2, 5], 2, 21)
sol.solve()
# Out:
# [10, 11, 12, 15, 20]

# %%
sol = Solution([], 2, 21)
sol.solve()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-116-c93209885010> in <module>
#       1 sol = Solution([], 2, 21)
# ----> 2 sol.solve()
#
# <ipython-input-113-ba6390d23882> in solve(self)
#      10     def solve(self):
#      11         if self.A==[]:
# ---> 12             raise Exception("Please provide non-empty list(A)")
#      13         elif self.B<=0 or self.C<=0:
#      14             raise Exception("Please provide the values of B and C are positive integers ")
#
# Exception: Please provide non-empty list(A)

# %%
sol = Solution([0, 1, 2, 5], 0, 1)
sol.solve()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-117-c14c9b369b87> in <module>
#       1 sol = Solution([0, 1, 2, 5], 0, 1)
# ----> 2 sol.solve()
#
# <ipython-input-113-ba6390d23882> in solve(self)
#      12             raise Exception("Please provide non-empty list(A)")
#      13         elif self.B<=0 or self.C<=0:
# ---> 14             raise Exception("Please provide the values of B and C are positive integers ")
#      15
#      16         from itertools import combinations_with_replacement
#
# Exception: Please provide the values of B and C are positive integers

# %%
sol = Solution([1], 2, 30)
sol.solve()
# Out:
# [11]

# %%
sol = Solution([0, 1, 2, 5], 2, 1)
sol.solve()
# Out:
# []
